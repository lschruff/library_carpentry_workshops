# %%
import matplotlib
import pandas as pd
import urllib.request

# %% [markdown]
# ## Daten herunterladen und einlesen

# %%
# Datei für Files-Daten herunterladen
url_data_files = "https://raw.githubusercontent.com/lschruff/library_carpentry_workshops/refs/heads/main/pandas_python_lesson/2025-12-01_frl_export_files.csv"
filename_files = "frl_export_files.csv"
urllib.request.urlretrieve(url_data_files, filename_files)
# Out:
# ('frl_export_files.csv', <http.client.HTTPMessage at 0x25e92c53da0>)

# %%
# Daten in panas einlesen
df_files = pd.read_csv("frl_export_files.csv")

# %% [markdown]
# ## Dataframe anschauen

# %%
# Ganzen Dataframe ansehen
df_files
# Out:
#               @id accessScheme contentType    parentPid publishScheme  \
# 0     frl:6489464       public        file  frl:6489463        public
# 1     frl:6489469       public        file  frl:6489468        public
# 2     frl:6489471       public        file  frl:6489470        public
# 3     frl:6489473       public        file  frl:6489472        public
# 4     frl:6489478       public        file  frl:6489467        public
# ...           ...          ...         ...          ...           ...
# 1209  frl:6526453       public        file  frl:6526450        public
# 1210  frl:6526454       public        file  frl:6526383        public
# 1211  frl:6526456       public        file  frl:6526455        public
# 1212  frl:6526457       public        file  frl:6526450        public
# 1213  frl:6526459       public        file  frl:6526431        public
#
#         hasData_checksum_checksumValue  \
# 0     c490ca6b23c5e4048f1eb0b231050990
# 1     6aded9fcd83c7bd62084ac33d985540e
# 2     5ab54c8303318337881f293718f694f7
# 3     28c5a18561c612ba8108ea7f9eda88c1
# 4     eb6626b1c7f0ff5799d688640852cb76
# ...                                ...
# 1209  cc73bafe51bcad41b0aaa3046548080e
# 1210  315c7a4bd8796c9165547f6721d06cfd
# 1211  93dfa42787d5ea1f046376f8d7d4bfd1
# 1212  cc73bafe51bcad41b0aaa3046548080e
# 1213  60a4425bac682efbf33f376d7c487f63
#
#                                       hasData_fileLabel   hasData_format  \
# 0                      LfULG_Schriftenreihe_11_2024.pdf  application/pdf
# 1                      LfULG_Schriftenreihe_14_2024.pdf  application/pdf
# 2                      LfULG_Schriftenreihe_13_2024.pdf  application/pdf
# 3     FOM-Forschung-ifgs-Schriftenreihe-31-Behrens-e...  application/pdf
# 4     IGB_Dossier_Naehrstoffbelastung_Arendsee_final...  application/pdf
# ...                                                 ...              ...
# 1209                                UFZReport2022_1.pdf  application/pdf
# 1210  wido_arz_Der GKV-Arzneimittelmarkt_Klassifikat...  application/pdf
# 1211                        efs78Waldkolloquium2025.pdf  application/pdf
# 1212                                UFZReport2022_1.pdf  application/pdf
# 1213                          DFG GZ SI27371-1 öff.pdf  application/pdf
#
#       hasData_size         isDescribedBy_created  isDescribedBy_createdBy
# 0         13647585  2025-01-08T14:06:26.786+0100                     18.0
# 1          7371321  2025-01-13T13:54:48.409+0100                     18.0
# 2          1580236  2025-01-13T14:05:47.602+0100                     18.0
# 3          7959219  2025-01-13T15:16:20.336+0100                     26.0
# 4          3393073  2025-01-16T09:10:55.128+0100                    339.0
# ...            ...                           ...                      ...
# 1209        841395  2025-11-26T12:27:44.776+0100                     20.0
# 1210       4350149  2025-11-27T06:59:29.881+0100                    339.0
# 1211       6031463  2025-11-27T10:31:13.661+0100                     22.0
# 1212        841395  2025-11-27T12:22:59.492+0100                     20.0
# 1213       3136646  2025-11-28T07:55:08.001+0100                    288.0
#
# [1214 rows x 11 columns]

# %%
# Setzt die Anzahl der angezeigten Zeilen hoch
pd.set_option("display.max_rows", 100)

# %%
# Umfang des DataFrames anzeigen
df_files.shape
# Out:
# (1214, 11)

# %%
# Liste der Spaltenüberschriften anzeigen - Variante 1
df_files.columns
# Out:
# Index(['@id', 'accessScheme', 'contentType', 'parentPid', 'publishScheme',
#        'hasData_checksum_checksumValue', 'hasData_fileLabel', 'hasData_format',
#        'hasData_size', 'isDescribedBy_created', 'isDescribedBy_createdBy'],
#       dtype='object')

# %%
# Liste der Spaltenüberschriften anzeigen - Variante 2
df_files.keys()
# Out:
# Index(['@id', 'accessScheme', 'contentType', 'parentPid', 'publishScheme',
#        'hasData_checksum_checksumValue', 'hasData_fileLabel', 'hasData_format',
#        'hasData_size', 'isDescribedBy_created', 'isDescribedBy_createdBy'],
#       dtype='object')

# %% [markdown]
# ## Mit Spalten arbeiten

# %%
# Nur die Werte einer Spalte anzeigen
df_files["hasData_size"]
# Out:
# 0       13647585
# 1        7371321
# 2        1580236
# 3        7959219
# 4        3393073
#           ...
# 1209      841395
# 1210     4350149
# 1211     6031463
# 1212      841395
# 1213     3136646
# Name: hasData_size, Length: 1214, dtype: int64

# %%
# Neue Spalte hinzufügen
df_files["hasData_size_mb"] = df_files["hasData_size"]

# %%
# Werte der Spalte umformen (Bytes => MB)
df_files["hasData_size_mb"] = df_files["hasData_size_mb"] * 0.000001

# %%
# Datentyp der Werte ändern (float=>int)
df_files["hasData_size_mb"] = df_files["hasData_size_mb"].astype(int)

# %%
# neue Spalte anzeigen
df_files["hasData_size_mb"]
# Out:
# 0       13
# 1        7
# 2        1
# 3        7
# 4        3
#         ..
# 1209     0
# 1210     4
# 1211     6
# 1212     0
# 1213     3
# Name: hasData_size_mb, Length: 1214, dtype: int64

# %%
# Spalte umbenennen
df_files.rename(columns={"hasData_size": "hasData_size_bytes"}, inplace=True)

# %%
# Liste der Spaltenüberschriften erneut anzeigen lassen
df_files.columns
# Out:
# Index(['@id', 'accessScheme', 'contentType', 'parentPid', 'publishScheme',
#        'hasData_checksum_checksumValue', 'hasData_fileLabel', 'hasData_format',
#        'hasData_size_bytes', 'isDescribedBy_created',
#        'isDescribedBy_createdBy', 'hasData_size_mb'],
#       dtype='object')

# %%
# Liste der Spaltenüberschriften durchsuchen
for key in df_files.columns:
    if "hasData_size" in key:
        print(key)
# Out:
# hasData_size_bytes
# hasData_size_mb

# %% [markdown]
# ## Werte analysieren

# %%
df_files["hasData_size_mb"].describe()
# Out:
# count    1214.000000
# mean        5.090610
# std        22.407822
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         4.000000
# max       589.000000
# Name: hasData_size_mb, dtype: float64

# %%
df_files["hasData_size_mb"].median().astype(int)
# Out:
# np.int64(1)

# %% [markdown]
# ## DataFrame filtern

# %%
# Welche Dateien sind größer als 50 MB?
df_files["hasData_size_mb"] >= 50
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1209    False
# 1210    False
# 1211    False
# 1212    False
# 1213    False
# Name: hasData_size_mb, Length: 1214, dtype: bool

# %%
# Filtere DataFrame nach dieser Bedingung
df_files[df_files["hasData_size_mb"] >= 50]
# Out:
#               @id accessScheme contentType    parentPid publishScheme  \
# 132   frl:6510240       public        file  frl:6510215        public
# 175   frl:6510333       public        file  frl:6510306        public
# 285   frl:6510786       public        file  frl:6510757        public
# 509   frl:6511249       public        file  frl:6510298        public
# 530   frl:6511301       public        file  frl:6511165        public
# 566   frl:6511383       public        file  frl:6511298        public
# 631   frl:6511609       public        file  frl:6511346        public
# 653   frl:6511670       public        file  frl:6511614        public
# 716   frl:6511901       public        file  frl:6511894        public
# 856   frl:6525003       public        file  frl:6524885        public
# 1029  frl:6525596       public        file  frl:6525595        public
# 1107  frl:6526142       public        file  frl:6495311        public
# 1178  frl:6526351       public        file  frl:6511264        public
#
#         hasData_checksum_checksumValue  \
# 132   26c0282419a246d860a27c468b8d9980
# 175   b2e84e3b3ad571f2623b809be88f3085
# 285   29bcc635bbaadb4548f25580417916e9
# 509   bafceb7ea93f8776480fda9e1538de5d
# 530   ec0323b772f9b181480917c7670a30df
# 566   03d6368770f5bbc30a1135cfadc71e09
# 631   43aaa5e454dfe7083995d4374ce43664
# 653   f51c4045ed2eb074fbec815fbf321938
# 716   4fd205ae90e65e8e56fccd31ede16c5d
# 856   46736de04b1523f3337d472574de93da
# 1029  49864fd4cf9fb6292a185c495a872077
# 1107  b661bc1f7fc2d3e7a7382f60ae59955e
# 1178  0b9690a7f36edf62839fa0ce75990147
#
#                                       hasData_fileLabel   hasData_format  \
# 132   VACCELERATE SHOWCASE EVENT JANUARY 23 2025_ Pr...        video/mp4
# 175                                 video1349932953.mp4        video/mp4
# 285   Global Guideline for the Diagnosis and Managem...        video/mp4
# 509   Habilitationsschrift_zellbasierteImmunoassays_...  application/pdf
# 530   Global Guideline Diagnosis and Management of C...        video/mp4
# 566   Antifungal Prophylaxis and Stewardship in HSCT...        video/mp4
# 631   VACCELERATE WEBINAR Data Interoperability in C...        video/mp4
# 653   VACCELERATE WEBINAR May 22 2024_ Willingness o...        video/mp4
# 716   2025 Bodey Lecture_ Hematological Cancer and I...        video/mp4
# 856                 Adverse events and side effects.mp4        video/mp4
# 1029                                JaBe2024_Band70.pdf  application/pdf
# 1107  Management of Invasive Mould Disease - Keynote...        video/mp4
# 1178                              EPIRESEHA_webinar.mp4        video/mp4
#
#       hasData_size_bytes         isDescribedBy_created  \
# 132            110881777  2025-02-27T10:36:46.420+0100
# 175             61888889  2025-03-07T08:00:52.395+0100
# 285             55726514  2025-03-25T10:46:31.493+0100
# 509            200260966  2025-05-09T13:06:30.007+0200
# 530            589613575  2025-05-14T07:11:49.062+0200
# 566            137438448  2025-05-15T16:21:32.116+0200
# 631            107503474  2025-06-02T10:31:28.589+0200
# 653             87053869  2025-06-05T09:58:11.315+0200
# 716            152182369  2025-06-26T08:01:33.048+0200
# 856             71146896  2025-07-11T10:50:42.433+0200
# 1029            80484225  2025-08-19T11:53:03.641+0200
# 1107            76753608  2025-09-01T10:18:17.262+0200
# 1178           316075210  2025-10-30T08:50:36.820+0100
#
#       isDescribedBy_createdBy  hasData_size_mb
# 132                     288.0              110
# 175                     288.0               61
# 285                     288.0               55
# 509                     339.0              200
# 530                     288.0              589
# 566                     288.0              137
# 631                     288.0              107
# 653                     288.0               87
# 716                     339.0              152
# 856                     288.0               71
# 1029                     22.0               80
# 1107                    288.0               76
# 1178                    288.0              316

# %%
# Filtere Dataframe, aber zeig mir nur die genannten Spalten an
df_files[df_files["hasData_size_mb"] >= 50][["@id", "hasData_format", "hasData_size_mb"]]
# Out:
#               @id   hasData_format  hasData_size_mb
# 132   frl:6510240        video/mp4              110
# 175   frl:6510333        video/mp4               61
# 285   frl:6510786        video/mp4               55
# 509   frl:6511249  application/pdf              200
# 530   frl:6511301        video/mp4              589
# 566   frl:6511383        video/mp4              137
# 631   frl:6511609        video/mp4              107
# 653   frl:6511670        video/mp4               87
# 716   frl:6511901        video/mp4              152
# 856   frl:6525003        video/mp4               71
# 1029  frl:6525596  application/pdf               80
# 1107  frl:6526142        video/mp4               76
# 1178  frl:6526351        video/mp4              316

# %%
# Teilmenge als neuen Dataframe speichern
df_file_size_over_50 = df_files[df_files["hasData_size_mb"] >= 50][["@id", "hasData_format", "hasData_size_mb", "isDescribedBy_createdBy"]]
df_file_size_over_50.shape
# Out:
# (13, 4)

# %%
# Dataframe sortieren (und mit der Pandas-Doku arbeiten (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html))
df_file_size_over_50_sorted = df_file_size_over_50.sort_values(by=["hasData_size_mb"], ascending=False)
df_file_size_over_50_sorted
# Out:
#               @id   hasData_format  hasData_size_mb  isDescribedBy_createdBy
# 530   frl:6511301        video/mp4              589                    288.0
# 1178  frl:6526351        video/mp4              316                    288.0
# 509   frl:6511249  application/pdf              200                    339.0
# 716   frl:6511901        video/mp4              152                    339.0
# 566   frl:6511383        video/mp4              137                    288.0
# 132   frl:6510240        video/mp4              110                    288.0
# 631   frl:6511609        video/mp4              107                    288.0
# 653   frl:6511670        video/mp4               87                    288.0
# 1029  frl:6525596  application/pdf               80                     22.0
# 1107  frl:6526142        video/mp4               76                    288.0
# 856   frl:6525003        video/mp4               71                    288.0
# 175   frl:6510333        video/mp4               61                    288.0
# 285   frl:6510786        video/mp4               55                    288.0

# %%
# Werte einer Spalte ersetzen
df_file_size_over_50_sorted["isDescribedBy_createdBy"] = df_file_size_over_50_sorted["isDescribedBy_createdBy"].replace(288.0, "personA").replace(339.0, "personB").replace(22.0, "personC")
df_file_size_over_50_sorted
# Out:
#               @id   hasData_format  hasData_size_mb isDescribedBy_createdBy
# 530   frl:6511301        video/mp4              589                 personA
# 1178  frl:6526351        video/mp4              316                 personA
# 509   frl:6511249  application/pdf              200                 personB
# 716   frl:6511901        video/mp4              152                 personB
# 566   frl:6511383        video/mp4              137                 personA
# 132   frl:6510240        video/mp4              110                 personA
# 631   frl:6511609        video/mp4              107                 personA
# 653   frl:6511670        video/mp4               87                 personA
# 1029  frl:6525596  application/pdf               80                 personC
# 1107  frl:6526142        video/mp4               76                 personA
# 856   frl:6525003        video/mp4               71                 personA
# 175   frl:6510333        video/mp4               61                 personA
# 285   frl:6510786        video/mp4               55                 personA

# %%
# Dataframe als Datei speichern
df_file_size_over_50_sorted.to_csv("df_file_size_over_50_sorted.csv")

# %% [markdown]
# ## Histogramme/Diagramme

# %%
# Einfaches Histogramm
df_file_size_over_50_sorted["hasData_size_mb"].hist()
# Out:
# <Axes: >

# %%
# Farbe ändern
df_file_size_over_50_sorted["hasData_size_mb"].hist(color="green")
# Out:
# <Axes: >

# %% [markdown]
# ## GroupBy

# %%
# Dataframe nach Spalte gruppieren
df_file_size_over_50_sorted_grouped = df_file_size_over_50_sorted.groupby("isDescribedBy_createdBy").sum("hasData_size_mb")
df_file_size_over_50_sorted_grouped
# Out:
#                          hasData_size_mb
# isDescribedBy_createdBy
# personA                             1609
# personB                              352
# personC                               80

# %%
# Waagrechtes Diagramm plotten
df_file_size_over_50_sorted_grouped.plot.barh()
# Out:
# <Axes: ylabel='isDescribedBy_createdBy'>

# %% [markdown]
# ## Zwei Dataframes mergen

# %%
# Datei für PMD-Daten herunterladen
# * PMD = PublikationsMetaDaten
url_data_pmd = "https://raw.githubusercontent.com/lschruff/library_carpentry_workshops/refs/heads/main/pandas_python_lesson/2025-12-01_frl_export_pmd.csv"
filename_pmd = "frl_export_pmd.csv"

urllib.request.urlretrieve(url_data_pmd, filename_pmd)
# Out:
# ('frl_export_pmd.csv', <http.client.HTTPMessage at 0x25eabbe93a0>)

# %%
# Zweiten Dataframe einlesen
df_pmd = pd.read_csv("frl_export_pmd.csv")
df_pmd.shape
# Out:
# (1201, 10)

# %%
# Spaltenüberschriften des zweiten Dataframes
df_pmd.columns
# Out:
# Index(['@id', 'abstractText', 'accessScheme', 'bibliographicCitation',
#        'creator', 'issued', 'language', 'title', 'isDescribedBy_created',
#        'isDescribedBy_createdBy'],
#       dtype='object')

# %%
# Spaltenüberschriften des ersten Dataframes
df_files.columns
# Out:
# Index(['@id', 'accessScheme', 'contentType', 'parentPid', 'publishScheme',
#        'hasData_checksum_checksumValue', 'hasData_fileLabel', 'hasData_format',
#        'hasData_size_bytes', 'isDescribedBy_created',
#        'isDescribedBy_createdBy', 'hasData_size_mb'],
#       dtype='object')

# %% [markdown]
# ### Spaltenüberschriften fürs Mergen vorbereiten

# %%
# Kopie beider Dataframes machen
df_files_copy = df_files.copy()
df_pmd_copy = df_pmd.copy()

# %%
# Alle Spaltenüberschriften mit "_pmd" anreichern
for key in df_pmd_copy.columns:
    df_pmd_copy.rename(columns={key: f"{key}_pmd"}, inplace=True)
df_pmd_copy.columns
# Out:
# Index(['@id_pmd', 'abstractText_pmd', 'accessScheme_pmd',
#        'bibliographicCitation_pmd', 'creator_pmd', 'issued_pmd',
#        'language_pmd', 'title_pmd', 'isDescribedBy_created_pmd',
#        'isDescribedBy_createdBy_pmd'],
#       dtype='object')

# %%
# Alle Spaltenüberschriften außer "parentPid" mit "_file" anreichern
for key in df_files_copy.columns:
    if key == "parentPid":
        pass
    else:
        df_files_copy.rename(columns={key: f"{key}_file"}, inplace=True)
df_files_copy.columns
# Out:
# Index(['@id_file', 'accessScheme_file', 'contentType_file', 'parentPid',
#        'publishScheme_file', 'hasData_checksum_checksumValue_file',
#        'hasData_fileLabel_file', 'hasData_format_file',
#        'hasData_size_bytes_file', 'isDescribedBy_created_file',
#        'isDescribedBy_createdBy_file', 'hasData_size_mb_file'],
#       dtype='object')

# %%
# Schlüsselspalte umbenennen
df_pmd_copy.rename(columns={"@id_pmd": "parentPid"}, inplace=True)

# %%
# Spaltenüberschriften des zweiten Dataframes erneut anzeigen
df_pmd_copy.columns
# Out:
# Index(['parentPid', 'abstractText_pmd', 'accessScheme_pmd',
#        'bibliographicCitation_pmd', 'creator_pmd', 'issued_pmd',
#        'language_pmd', 'title_pmd', 'isDescribedBy_created_pmd',
#        'isDescribedBy_createdBy_pmd'],
#       dtype='object')

# %%
# Dataframes mergen
df_frl_merged = df_files_copy.merge(df_pmd_copy, how="left", on="parentPid")
df_frl_merged.shape
# Out:
# (1214, 21)

# %%
# Spaltenüberschriften anschauen
df_frl_merged.columns
# Out:
# Index(['@id_file', 'accessScheme_file', 'contentType_file', 'parentPid',
#        'publishScheme_file', 'hasData_checksum_checksumValue_file',
#        'hasData_fileLabel_file', 'hasData_format_file',
#        'hasData_size_bytes_file', 'isDescribedBy_created_file',
#        'isDescribedBy_createdBy_file', 'hasData_size_mb_file',
#        'abstractText_pmd', 'accessScheme_pmd', 'bibliographicCitation_pmd',
#        'creator_pmd', 'issued_pmd', 'language_pmd', 'title_pmd',
#        'isDescribedBy_created_pmd', 'isDescribedBy_createdBy_pmd'],
#       dtype='object')

# %%
# Nur die Zeilen ausgeben, für die Dateigröße >= 50 MB
df_frl_merged[df_frl_merged["hasData_size_mb_file"] >= 50]
# Out:
#          @id_file accessScheme_file contentType_file    parentPid  \
# 132   frl:6510240            public             file  frl:6510215
# 175   frl:6510333            public             file  frl:6510306
# 285   frl:6510786            public             file  frl:6510757
# 509   frl:6511249            public             file  frl:6510298
# 530   frl:6511301            public             file  frl:6511165
# 566   frl:6511383            public             file  frl:6511298
# 631   frl:6511609            public             file  frl:6511346
# 653   frl:6511670            public             file  frl:6511614
# 716   frl:6511901            public             file  frl:6511894
# 856   frl:6525003            public             file  frl:6524885
# 1029  frl:6525596            public             file  frl:6525595
# 1107  frl:6526142            public             file  frl:6495311
# 1178  frl:6526351            public             file  frl:6511264
#
#      publishScheme_file hasData_checksum_checksumValue_file  \
# 132              public    26c0282419a246d860a27c468b8d9980
# 175              public    b2e84e3b3ad571f2623b809be88f3085
# 285              public    29bcc635bbaadb4548f25580417916e9
# 509              public    bafceb7ea93f8776480fda9e1538de5d
# 530              public    ec0323b772f9b181480917c7670a30df
# 566              public    03d6368770f5bbc30a1135cfadc71e09
# 631              public    43aaa5e454dfe7083995d4374ce43664
# 653              public    f51c4045ed2eb074fbec815fbf321938
# 716              public    4fd205ae90e65e8e56fccd31ede16c5d
# 856              public    46736de04b1523f3337d472574de93da
# 1029             public    49864fd4cf9fb6292a185c495a872077
# 1107             public    b661bc1f7fc2d3e7a7382f60ae59955e
# 1178             public    0b9690a7f36edf62839fa0ce75990147
#
#                                  hasData_fileLabel_file hasData_format_file  \
# 132   VACCELERATE SHOWCASE EVENT JANUARY 23 2025_ Pr...           video/mp4
# 175                                 video1349932953.mp4           video/mp4
# 285   Global Guideline for the Diagnosis and Managem...           video/mp4
# 509   Habilitationsschrift_zellbasierteImmunoassays_...     application/pdf
# 530   Global Guideline Diagnosis and Management of C...           video/mp4
# 566   Antifungal Prophylaxis and Stewardship in HSCT...           video/mp4
# 631   VACCELERATE WEBINAR Data Interoperability in C...           video/mp4
# 653   VACCELERATE WEBINAR May 22 2024_ Willingness o...           video/mp4
# 716   2025 Bodey Lecture_ Hematological Cancer and I...           video/mp4
# 856                 Adverse events and side effects.mp4           video/mp4
# 1029                                JaBe2024_Band70.pdf     application/pdf
# 1107  Management of Invasive Mould Disease - Keynote...           video/mp4
# 1178                              EPIRESEHA_webinar.mp4           video/mp4
#
#       hasData_size_bytes_file    isDescribedBy_created_file  ...  \
# 132                 110881777  2025-02-27T10:36:46.420+0100  ...
# 175                  61888889  2025-03-07T08:00:52.395+0100  ...
# 285                  55726514  2025-03-25T10:46:31.493+0100  ...
# 509                 200260966  2025-05-09T13:06:30.007+0200  ...
# 530                 589613575  2025-05-14T07:11:49.062+0200  ...
# 566                 137438448  2025-05-15T16:21:32.116+0200  ...
# 631                 107503474  2025-06-02T10:31:28.589+0200  ...
# 653                  87053869  2025-06-05T09:58:11.315+0200  ...
# 716                 152182369  2025-06-26T08:01:33.048+0200  ...
# 856                  71146896  2025-07-11T10:50:42.433+0200  ...
# 1029                 80484225  2025-08-19T11:53:03.641+0200  ...
# 1107                 76753608  2025-09-01T10:18:17.262+0200  ...
# 1178                316075210  2025-10-30T08:50:36.820+0100  ...
#
#       hasData_size_mb_file                                   abstractText_pmd  \
# 132                    110  ['VACCELERATE is a European network dedicated ...
# 175                     61  ["Welcome to the video series of the Global Gu...
# 285                     55  ["Welcome to the video series of the Global Gu...
# 509                    200                                                NaN
# 530                    589  ["Welcome to the video series of the Global Gu...
# 566                    137  ['Invasive fungal infections remain a major ca...
# 631                    107  ['We are excited to invite you to watch this i...
# 653                     87  ['Willingness of EU medical and paramedical st...
# 716                    152  ['In this video, we share the 2025 Bodey Lectu...
# 856                     71  ['This episode is part of “MedFacts with Prof....
# 1029                    80                                                NaN
# 1107                    76  ['Join Prof. Dr. Oliver A. Cornely at the 4th ...
# 1178                   316  ["With: Francesco Marchesi (IRCCS Istituto Naz...
#
#      accessScheme_pmd bibliographicCitation_pmd  \
# 132            public                       NaN
# 175            public                       NaN
# 285            public                       NaN
# 509            public                       NaN
# 530            public                       NaN
# 566            public                       NaN
# 631            public                       NaN
# 653            public                       NaN
# 716            public                       NaN
# 856            public                       NaN
# 1029           public                       NaN
# 1107           public                       NaN
# 1178           public                       NaN
#
#                                             creator_pmd issued_pmd  \
# 132   [{'prefLabel': 'Cornely, Oliver Andreas', '@id...     2025.0
# 175   [{'prefLabel': 'Rautemaa-Richardson, Riina', '...     2025.0
# 285   [{'prefLabel': 'Vinh, Donald C.', '@id': 'http...     2025.0
# 509   [{'prefLabel': 'Dammermann, Werner', '@id': 'h...     2023.0
# 530   [{'prefLabel': 'Groll, Andreas Hermann', '@id'...     2025.0
# 566   [{'prefLabel': 'Gabriēlakē, Elenē', '@id': 'ht...     2025.0
# 631   [{'prefLabel': 'Pana, Zoi-Dorothea', '@id': 'h...     2025.0
# 653   [{'prefLabel': 'Yiallouris, Andreas', '@id': '...     2025.0
# 716   [{'prefLabel': 'Cornely, Oliver Andreas', '@id...     2025.0
# 856   [{'prefLabel': 'Schmitt, Joe', '@id': 'https:/...     2025.0
# 1029  [{'prefLabel': 'Institut für Binnenfischerei (...     2025.0
# 1107  [{'prefLabel': 'Cornely, Oliver Andreas', '@id...     2025.0
# 1178  [{'prefLabel': 'Pagano, Livio', '@id': 'https:...     2025.0
#
#                                            language_pmd  \
# 132   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 175   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 285   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 509   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 530   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 566   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 631   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 653   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 716   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 856   [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 1029  [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 1107  [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
# 1178  [{'@id': 'http://id.loc.gov/vocabulary/iso639-...
#
#                                               title_pmd  \
# 132                      ['VACCELERATE showcase event']
# 175   ['Global guideline for the diagnosis and manag...
# 285   ['Global guideline for the diagnosis and manag...
# 509   ['Zellbasierte Immunoassays in Diagnostik und ...
# 530   ['Global guideline for the diagnosis and manag...
# 566   ['Antifungal prophylaxis and stewardship in HS...
# 631   ['Data interoperability in COVID-19 vaccine tr...
# 653                             ['VACCELERATE webinar']
# 716   ['Hematological cancer and infectious disease ...
# 856   ['MedFacts with Prof. Joe Schmitt: Adverse eve...
# 1029                            ['Jahresbericht, 2024']
# 1107           ['Management of invasive mould disease']
# 1178                              ['EPIRESEHA Webinar']
#
#          isDescribedBy_created_pmd isDescribedBy_createdBy_pmd
# 132   2025-02-25T09:09:12.984+0100                       338.0
# 175   2025-03-05T11:16:50.106+0100                       338.0
# 285   2025-03-21T11:03:44.460+0100                       338.0
# 509   2025-02-28T17:51:49.498+0100                       339.0
# 530   2025-05-05T09:01:34.177+0200                       338.0
# 566   2025-05-13T09:19:32.365+0200                       338.0
# 631   2025-05-15T09:49:20.544+0200                       338.0
# 653   2025-06-02T12:06:40.614+0200                       338.0
# 716   2025-06-24T15:02:54.051+0200                       338.0
# 856   2025-07-07T09:03:52.202+0200                       338.0
# 1029  2025-08-19T11:51:16.345+0200                        22.0
# 1107  2025-02-04T08:15:10.868+0100                       338.0
# 1178  2025-05-09T14:13:07.238+0200                       338.0
#
# [13 rows x 21 columns]
